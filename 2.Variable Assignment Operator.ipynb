# %%
num1=10
num2=20
add=num1+num2
print("add")

# %%
num1=10
num2=25
add=num1+num2
print(add)

# %%
First Name="Dharmaprabhu D"

# %%
FirstName="Dharmaprabhu D"

# %%
print("The Addition of two numbers")
num1=10
print("The Number1:",num1)
num2=25
print("The Number2:",num2)
print("The Answer:",num1+num2)

# %%
print("The Addition of two numbers")
num1=10
print("The Number1:",num1)
num2=25
print("The Number2:",num2)
add=num1+num2
print("The Answer:",add)

# %%
num1=int(input("Enter the num1:"))
# Out:
# Enter the num1: 30

# %%
num2=int(input("Enter the num2:"))
# Out:
# Enter the num2: 50

# %%
add=num1+num2
print(add)
# Out:
# 80
