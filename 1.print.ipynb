# %%
print()

# %%
print("Thanks for welcoming Hope Ai")
# Out:
# Thanks for welcoming Hope Ai

# %%
Print("hello")
# Out:
# --------------------------------------------------
# NameError        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print("hello")
#
# NameError: name 'Print' is not defined
